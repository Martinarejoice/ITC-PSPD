# %%
import json

# %%
# Load inventory data
def load_inventory(filename):
    with open(filename, 'r') as f:
        return json.load(f)

# %%
# Calculate total inventory value
def calculate_total_value(inventory):
    return sum(item['quantity_kg'] * item['cost_per_kg'] for item in inventory)

# %%
# Identify low inventory items
def identify_low_stock(inventory):
    return [item for item in inventory if item['quantity_kg'] < item['threshold_kg']]

# %%
# Generate summary report
def generate_summary(inventory):
    print(" Fiber Inventory Summary:")
    for item in inventory:
        print(f"- Type: {item['type']}")
        print(f"  Quantity: {item['quantity_kg']} kg")
        print(f"  Cost per kg: ₹{item['cost_per_kg']}")
        print(f"  Quality Rating: {item['quality']}/10")
        print()

# %%
# Compute basic statistics
def inventory_statistics(inventory):
    total_qty = sum(item['quantity_kg'] for item in inventory)
    avg_quality = round(sum(item['quality'] for item in inventory) / len(inventory), 2)
    return {
        "total_quantity": total_qty,
        "average_quality": avg_quality
    }

# %%
# Main function
def main():
    inventory = load_inventory('fiber_inventory.json')
    
    print("=========== Inventory Report ===========")
    generate_summary(inventory)
    
    total_value = calculate_total_value(inventory)
    print(f" Total Inventory Value: ₹{total_value:.2f}")
    
    stats = inventory_statistics(inventory)
    print(f" Total Quantity: {stats['total_quantity']} kg")
    print(f" Average Quality: {stats['average_quality']} / 10")

    low_stock = identify_low_stock(inventory)
    if low_stock:
        print("\n Low Inventory Alerts:")
        for item in low_stock:
            print(f"- {item['type']} fiber is below threshold! (Current: {item['quantity_kg']} kg, Threshold: {item['threshold_kg']} kg)")
    else:
        print("\n All inventory levels are sufficient.")

# %%
if __name__ == "__main__":
    main()
# Out:
# =========== Inventory Report ===========
#  Fiber Inventory Summary:
# - Type: softwood
#   Quantity: 500 kg
#   Cost per kg: ₹1.2
#   Quality Rating: 8.5/10
#
# - Type: hardwood
#   Quantity: 200 kg
#   Cost per kg: ₹1.5
#   Quality Rating: 9.0/10
#
# - Type: recycled
#   Quantity: 1000 kg
#   Cost per kg: ₹0.8
#   Quality Rating: 7.5/10
#
# - Type: softwood
#   Quantity: 350 kg
#   Cost per kg: ₹1.3
#   Quality Rating: 8.2/10
#
# - Type: hardwood
#   Quantity: 150 kg
#   Cost per kg: ₹1.6
#   Quality Rating: 8.9/10
#
# - Type: recycled
#   Quantity: 600 kg
#   Cost per kg: ₹0.75
#   Quality Rating: 6.8/10
#
# - Type: softwood
#   Quantity: 700 kg
#   Cost per kg: ₹1.1
#   Quality Rating: 9.0/10
#
# - Type: hardwood
#   Quantity: 220 kg
#   Cost per kg: ₹1.55
#   Quality Rating: 9.2/10
#
# - Type: recycled
#   Quantity: 450 kg
#   Cost per kg: ₹0.9
#   Quality Rating: 7.0/10
#
# - Type: softwood
#   Quantity: 275 kg
#   Cost per kg: ₹1.25
#   Quality Rating: 8.7/10
#
# - Type: hardwood
#   Quantity: 180 kg
#   Cost per kg: ₹1.65
#   Quality Rating: 9.1/10
#
# - Type: recycled
#   Quantity: 1050 kg
#   Cost per kg: ₹0.78
#   Quality Rating: 7.3/10
#
# - Type: softwood
#   Quantity: 620 kg
#   Cost per kg: ₹1.15
#   Quality Rating: 8.4/10
#
# - Type: hardwood
#   Quantity: 260 kg
#   Cost per kg: ₹1.7
#   Quality Rating: 9.3/10
#
# - Type: recycled
#   Quantity: 980 kg
#   Cost per kg: ₹0.85
#   Quality Rating: 7.6/10
#
# - Type: softwood
#   Quantity: 310 kg
#   Cost per kg: ₹1.3
#   Quality Rating: 8.8/10
#
# - Type: hardwood
#   Quantity: 300 kg
#   Cost per kg: ₹1.6
#   Quality Rating: 9.4/10
#
# - Type: recycled
#   Quantity: 700 kg
#   Cost per kg: ₹0.8
#   Quality Rating: 7.1/10
#
# - Type: softwood
#   Quantity: 480 kg
#   Cost per kg: ₹1.22
#   Quality Rating: 8.6/10
#
# - Type: hardwood
#   Quantity: 195 kg
#   Cost per kg: ₹1.58
#   Quality Rating: 8.8/10
#
# - Type: recycled
#   Quantity: 840 kg
#   Cost per kg: ₹0.82
#   Quality Rating: 7.4/10
#
# - Type: softwood
#   Quantity: 540 kg
#   Cost per kg: ₹1.19
#   Quality Rating: 8.3/10
#
# - Type: hardwood
#   Quantity: 230 kg
#   Cost per kg: ₹1.62
#   Quality Rating: 9.2/10
#
# - Type: recycled
#   Quantity: 910 kg
#   Cost per kg: ₹0.79
#   Quality Rating: 7.7/10
#
# - Type: softwood
#   Quantity: 295 kg
#   Cost per kg: ₹1.28
#   Quality Rating: 8.9/10
#
# - Type: hardwood
#   Quantity: 270 kg
#   Cost per kg: ₹1.66
#   Quality Rating: 9.0/10
#
# - Type: recycled
#   Quantity: 500 kg
#   Cost per kg: ₹0.88
#   Quality Rating: 7.2/10
#
# - Type: softwood
#   Quantity: 680 kg
#   Cost per kg: ₹1.17
#   Quality Rating: 8.2/10
#
# - Type: hardwood
#   Quantity: 310 kg
#   Cost per kg: ₹1.59
#   Quality Rating: 9.5/10
#
# - Type: recycled
#   Quantity: 1200 kg
#   Cost per kg: ₹0.76
#   Quality Rating: 7.5/10
#
# - Type: softwood
#   Quantity: 440 kg
#   Cost per kg: ₹1.24
#   Quality Rating: 8.7/10
#
#  Total Inventory Value: ₹16580.25
#  Total Quantity: 15735 kg
#  Average Quality: 8.35 / 10
#
#  Low Inventory Alerts:
# - hardwood fiber is below threshold! (Current: 200 kg, Threshold: 250 kg)
# - hardwood fiber is below threshold! (Current: 150 kg, Threshold: 200 kg)
# - hardwood fiber is below threshold! (Current: 220 kg, Threshold: 250 kg)
# - recycled fiber is below threshold! (Current: 450 kg, Threshold: 500 kg)
# - softwood fiber is below threshold! (Current: 275 kg, Threshold: 300 kg)
# - hardwood fiber is below threshold! (Current: 180 kg, Threshold: 250 kg)
# - hardwood fiber is below threshold! (Current: 195 kg, Threshold: 250 kg)
# - hardwood fiber is below threshold! (Current: 230 kg, Threshold: 250 kg)
# - softwood fiber is below threshold! (Current: 295 kg, Threshold: 300 kg)
